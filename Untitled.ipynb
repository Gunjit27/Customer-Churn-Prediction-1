# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
df = pd.read_csv('customer_churn.csv')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5270  6682-QJDGB    Male              0      No        Yes      40
# 3025  6651-RLGGM    Male              0     Yes        Yes      67
# 1375  1839-FBNFR  Female              0     Yes        Yes      39
# 2633  4837-QUSFT  Female              0     Yes         No      65
# 2308  3324-OIRTO    Male              0     Yes        Yes      71
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5270          Yes            No             DSL                  Yes  ...
# 3025          Yes           Yes              No  No internet service  ...
# 1375          Yes            No              No  No internet service  ...
# 2633          Yes           Yes     Fiber optic                  Yes  ...
# 2308          Yes            No     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5270                   No                   No                   No
# 3025  No internet service  No internet service  No internet service
# 1375  No internet service  No internet service  No internet service
# 2633                   No                  Yes                  Yes
# 2308                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 5270                   No  Month-to-month              Yes
# 3025  No internet service        Two year               No
# 1375  No internet service        Two year              Yes
# 2633                   No        One year              Yes
# 2308                  Yes        One year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 5270               Mailed check          55.25        2139.2   Yes
# 3025               Mailed check          26.30        1688.9    No
# 1375  Bank transfer (automatic)          19.85         854.8    No
# 2633  Bank transfer (automatic)         100.15        6643.5    No
# 2308  Bank transfer (automatic)         104.65        7288.4    No
#
# [5 rows x 21 columns]

# %%
df = df.drop('customerID',axis='columns')
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges,errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\gunji\AppData\Local\Temp\ipykernel_11992\973151263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
def print_unique_col_values(df):
    for col in df:
        if df[col].dtype=='object':
            print(f'{col}: {df[col].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# C:\Users\gunji\AppData\Local\Temp\ipykernel_11992\2045096646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)
# C:\Users\gunji\AppData\Local\Temp\ipykernel_11992\2045096646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_no_cols = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 
               'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']

for col in yes_no_cols:
    df1[col].replace('Yes',1,inplace=True)
    df1[col].replace('No',0,inplace=True)
# Out:
# C:\Users\gunji\AppData\Local\Temp\ipykernel_11992\4074565063.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace('Yes',1,inplace=True)
# C:\Users\gunji\AppData\Local\Temp\ipykernel_11992\4074565063.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace('No',0,inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# InternetService: ['DSL' 'Fiber optic' 'No']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
df1.replace('Female',1,inplace=True)
df1.replace('Male',0,inplace=True)
# Out:
# C:\Users\gunji\AppData\Local\Temp\ipykernel_11992\1710807556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('Female',1,inplace=True)
# C:\Users\gunji\AppData\Local\Temp\ipykernel_11992\1710807556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('Male',0,inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df2 = pd.get_dummies(data = df1, columns = ['InternetService' , 'Contract' , 'PaymentMethod'])
# df2 = df2.astype(int)
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2426       1              0        1           0      17             0
# 4001       0              0        1           1      45             1
# 1371       1              1        0           0       1             1
# 6285       0              0        0           0      26             0
# 1897       0              1        1           0      30             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 2426              0               0             1                 1  ...
# 4001              1               0             1                 1  ...
# 1371              0               0             0                 0  ...
# 6285              0               1             0                 0  ...
# 1897              0               0             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 2426                 True                        False               False
# 4001                False                         True               False
# 1371                False                         True               False
# 6285                 True                        False               False
# 1897                 True                        False               False
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 2426                     True              False              False
# 4001                    False              False               True
# 1371                     True              False              False
# 6285                    False               True              False
# 1897                     True              False              False
#
#       PaymentMethod_Bank transfer (automatic)  \
# 2426                                    False
# 4001                                     True
# 1371                                    False
# 6285                                    False
# 1897                                     True
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2426                                   True                           False
# 4001                                  False                           False
# 1371                                  False                            True
# 6285                                   True                           False
# 1897                                  False                           False
#
#       PaymentMethod_Mailed check
# 2426                       False
# 4001                       False
# 1371                       False
# 6285                       False
# 1897                       False
#
# [5 rows x 27 columns]

# %%
df2.replace(False,0,inplace=True)
df2.replace(True,1,inplace=True)

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          int64
# InternetService_Fiber optic                  int64
# InternetService_No                           int64
# Contract_Month-to-month                      int64
# Contract_One year                            int64
# Contract_Two year                            int64
# PaymentMethod_Bank transfer (automatic)      int64
# PaymentMethod_Credit card (automatic)        int64
# PaymentMethod_Electronic check               int64
# PaymentMethod_Mailed check                   int64
# dtype: object

# %%
cols_to_scale = ['tenure' , 'MonthlyCharges' , 'TotalCharges']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
x = df2.drop('Churn',axis='columns')
y = df2.Churn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.shape
# Out:
# (5625, 26)

# %%
x_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(x_train.columns)
# Out:
# 26

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(26,)))
model.add(keras.layers.Dense(26,activation='relu'))
model.add(keras.layers.Dense(20,activation='relu'))
model.add(keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5150 - accuracy: 0.7365
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.7932
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4187 - accuracy: 0.8012
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.8048
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8023
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4111 - accuracy: 0.8098
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4083 - accuracy: 0.8116
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8105
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4034 - accuracy: 0.8105
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4026 - accuracy: 0.8119
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8139
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3992 - accuracy: 0.8116
# Epoch 13/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3979 - accuracy: 0.8162
# Epoch 14/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8142
# Epoch 15/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8167
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8162
# Epoch 17/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8172
# Epoch 18/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8162
# Epoch 19/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3905 - accuracy: 0.8181
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3893 - accuracy: 0.8183
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8204
# Epoch 22/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3881 - accuracy: 0.8199
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8183
# Epoch 24/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3859 - accuracy: 0.8208
# Epoch 25/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8220
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8203
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8224
# Epoch 28/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8229
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3798 - accuracy: 0.8235
# Epoch 30/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8213
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8228
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.8212
# Epoch 33/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8267
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.8251
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3752 - accuracy: 0.8247
# Epoch 36/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3752 - accuracy: 0.8233
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8249
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8284
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8242
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3721 - accuracy: 0.8276
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8238
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8251
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.8279
# Epoch 44/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3691 - accuracy: 0.8274
# Epoch 45/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8283
# Epoch 46/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3685 - accuracy: 0.8281
# Epoch 47/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3675 - accuracy: 0.8279
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.8290
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3657 - accuracy: 0.8279
# Epoch 50/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3650 - accuracy: 0.8279
# Epoch 51/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3645 - accuracy: 0.8286
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.8302
# Epoch 53/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3637 - accuracy: 0.8286
# Epoch 54/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8325
# Epoch 55/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8329
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3610 - accuracy: 0.8318
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3612 - accuracy: 0.8302
# Epoch 58/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3607 - accuracy: 0.8311
# Epoch 59/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.8270
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3592 - accuracy: 0.8345
# Epoch 61/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3594 - accuracy: 0.8324
# Epoch 62/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3583 - accuracy: 0.8313
# Epoch 63/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8329
# Epoch 64/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3564 - accuracy: 0.8347
# Epoch 65/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.8354
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3551 - accuracy: 0.8320
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3547 - accuracy: 0.8347
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3547 - accuracy: 0.8361
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3537 - accuracy: 0.8356
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3543 - accuracy: 0.8357
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8368
# Epoch 72/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3533 - accuracy: 0.8345
# Epoch 73/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3511 - accuracy: 0.8388
# Epoch 74/100
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3520 - accuracy: 0.8356
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3511 - accuracy: 0.8354
# Epoch 76/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8364
# Epoch 77/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8380
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8345
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8372
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8389
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8391
# Epoch 82/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3484 - accuracy: 0.8356
# Epoch 83/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3483 - accuracy: 0.8384
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.8379
# Epoch 85/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8393
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.8364
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3456 - accuracy: 0.8391
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3441 - accuracy: 0.8391
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3466 - accuracy: 0.8395
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3447 - accuracy: 0.8402
# Epoch 91/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3441 - accuracy: 0.8400
# Epoch 92/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8391
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.8416
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8389
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8412
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3429 - accuracy: 0.8395
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8412
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3403 - accuracy: 0.8427
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.8425
# Epoch 100/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8420

# %%
model.evaluate(x_test,y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5062 - accuracy: 0.7662
# [0.5062490701675415, 0.7661691308021545]

# %%
yp = model.predict(x_test)
yp_int = []
for i in yp:
    if i>0.5:
        yp_int.append(1)
    else:
        yp_int.append(0)
yp_int[:10]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# [0, 0, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=yp_int)
plt.figure(figsize = (10,7))
sn.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
